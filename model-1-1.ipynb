# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import PIL
import tensorflow as tf
import torch
import torchvision.models as models
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.resnet import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.python.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from google.colab import drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_directory = '/content/drive/MyDrive/makanan'

# %%
print(os.listdir(data_directory))
# Out:
# ['telur_dadar', 'telur_balado', 'ayam_pop', 'dendeng_batokok', 'ayam_goreng', 'gulai_ikan', 'gulai_tunjang', 'gulai_tambusu', 'daging_rendang']

# %%
number_label = {}
total_files = 0
for i in os.listdir(data_directory):
    counting = len(os.listdir(os.path.join(data_directory, i)))
    number_label[i] = counting
    total_files += counting

print("Total Files : " + str(total_files))
# Out:
# Total Files : 1003

# %%
labels = list(number_label.keys())
counts = list(number_label.values())

plt.bar(labels, counts)
plt.title("Jumlah gambar")
plt.xlabel('Label', fontsize=10)
plt.ylabel('Jumlah Gambar', fontsize=10)

for i, count in enumerate(counts):
    plt.text(i, count, str(count), ha='center', va='bottom', fontsize=8)
plt.xticks(rotation='vertical')
plt.show()

# %%
import matplotlib.image as mpimg

img_each_class = 1
img_samples = {}
classes = list(number_label.keys())


for c in classes:
    temp = os.listdir(os.path.join(data_directory, c))[:img_each_class]
    for item in temp:
        img_path = os.path.join(data_directory, c, item)
        img_samples[c] = img_path

for i in img_samples:
    fig = plt.gcf()
    img = mpimg.imread(img_samples[i])
    plt.title(i)
    plt.imshow(img)
    plt.show()

# %%
IMAGE_SIZE = (224,224)
BATCH_SIZE = 32
SEED = 10000

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    validation_split=0.2
)

# %%
train_data = datagen.flow_from_directory(
    data_directory,
    class_mode='categorical',
    subset='training',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    seed=SEED
)
# Out:
# Found 807 images belonging to 9 classes.

# %%
label_counts = train_data.classes
unique_labels, counts = np.unique(label_counts, return_counts=True)
label_names = list(train_data.class_indices.keys())

plt.bar(label_names, counts)
plt.title("Jumlah gambar pelatihan untuk masing-masing kelas")
plt.xlabel('Label')
plt.ylabel('Jumlah Gambar')
plt.xticks(rotation='vertical')

for i, count in enumerate(counts):
    plt.text(i, count, str(count), ha='center', va='bottom')

plt.show()

# %%
valid_data = datagen.flow_from_directory(
    data_directory,
    class_mode='categorical',
    subset='validation',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    seed=SEED
)
# Out:
# Found 196 images belonging to 9 classes.

# %%
label_counts = valid_data.classes
unique_labels, counts = np.unique(label_counts, return_counts=True)
label_names = list(train_data.class_indices.keys())

plt.bar(label_names, counts)
plt.title("Jumlah gambar validasi untuk masing-masing kelas")
plt.xlabel('Label')
plt.ylabel('Jumlah Gambar')
plt.xticks(rotation='vertical')

for i, count in enumerate(counts):
    plt.text(i, count, str(count), ha='center', va='bottom')

plt.show()

# %%
class_labels = train_data.class_indices
code_to_label = {v: k for k, v in class_labels.items()}
print("Class Labels and Their Codes:")
for code, label in code_to_label.items():
    print(f"Code: {code}, Label: {label}")
# Out:
# Class Labels and Their Codes:
# Code: 0, Label: ayam_goreng
# Code: 1, Label: ayam_pop
# Code: 2, Label: daging_rendang
# Code: 3, Label: dendeng_batokok
# Code: 4, Label: gulai_ikan
# Code: 5, Label: gulai_tambusu
# Code: 6, Label: gulai_tunjang
# Code: 7, Label: telur_balado
# Code: 8, Label: telur_dadar

# %%
rescale = tf.keras.Sequential([
   layers.experimental.preprocessing.Resizing(224,224),
   layers.experimental.preprocessing.Rescaling(1./255),
])

# %%
num_classes = 9

# Assuming you have defined train_data_gen and train_data as mentioned above

base_resnet_model = tf.keras.applications.MobileNetV3Large(weights='imagenet', include_top=False, input_shape=(224, 224, 3), pooling='avg')
base_resnet_model.trainable = False

resnet_model = tf.keras.models.Sequential([
    base_resnet_model,
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 [==============================] - 0s 0us/step

# %%
initial_learning_rate = 0.0001
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,  # Initial learning rate
    decay_steps=1000,       # Decay learning rate every 'n' steps
    decay_rate=0.9,         # Decay rate
    staircase=True          # Whether to use staircase decay
)

# Compile the model with the custom learning rate
resnet_model.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    metrics=['accuracy']
)

# %%
resnet_hist = resnet_model.fit(
    train_data,
    epochs=200,
    validation_data=valid_data,
    steps_per_epoch=12
)
# Out:
# Epoch 1/200
# 12/12 [==============================] - 184s 15s/step - loss: 2.3813 - accuracy: 0.1560 - val_loss: 1.9730 - val_accuracy: 0.2500
# Epoch 2/200
# 12/12 [==============================] - 67s 6s/step - loss: 1.9440 - accuracy: 0.2943 - val_loss: 1.7325 - val_accuracy: 0.4694
# Epoch 3/200
# 12/12 [==============================] - 34s 3s/step - loss: 1.7457 - accuracy: 0.3880 - val_loss: 1.5088 - val_accuracy: 0.6122
# Epoch 4/200
# 12/12 [==============================] - 25s 2s/step - loss: 1.5178 - accuracy: 0.5286 - val_loss: 1.3207 - val_accuracy: 0.7143
# Epoch 5/200
# 12/12 [==============================] - 24s 2s/step - loss: 1.2770 - accuracy: 0.6657 - val_loss: 1.1595 - val_accuracy: 0.7449
# Epoch 6/200
# 12/12 [==============================] - 21s 2s/step - loss: 1.2027 - accuracy: 0.6693 - val_loss: 1.0272 - val_accuracy: 0.7959
# Epoch 7/200
# 12/12 [==============================] - 23s 2s/step - loss: 1.0878 - accuracy: 0.6936 - val_loss: 0.9142 - val_accuracy: 0.7857
# Epoch 8/200
# 12/12 [==============================] - 32s 3s/step - loss: 1.0202 - accuracy: 0.6927 - val_loss: 0.8176 - val_accuracy: 0.8010
# Epoch 9/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.8895 - accuracy: 0.7396 - val_loss: 0.7383 - val_accuracy: 0.8061
# Epoch 10/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.7872 - accuracy: 0.7855 - val_loss: 0.6806 - val_accuracy: 0.8520
# Epoch 11/200
# 12/12 [==============================] - 20s 2s/step - loss: 0.7453 - accuracy: 0.7716 - val_loss: 0.6390 - val_accuracy: 0.8520
# Epoch 12/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.6987 - accuracy: 0.8050 - val_loss: 0.5769 - val_accuracy: 0.8265
# Epoch 13/200
# 12/12 [==============================] - 20s 2s/step - loss: 0.6243 - accuracy: 0.8229 - val_loss: 0.5308 - val_accuracy: 0.8367
# Epoch 14/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.5962 - accuracy: 0.8411 - val_loss: 0.4994 - val_accuracy: 0.8571
# Epoch 15/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.5662 - accuracy: 0.8359 - val_loss: 0.4773 - val_accuracy: 0.8673
# Epoch 16/200
# 12/12 [==============================] - 20s 2s/step - loss: 0.4875 - accuracy: 0.8750 - val_loss: 0.4490 - val_accuracy: 0.8673
# Epoch 17/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.4256 - accuracy: 0.8958 - val_loss: 0.4268 - val_accuracy: 0.8469
# Epoch 18/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.3901 - accuracy: 0.8906 - val_loss: 0.4030 - val_accuracy: 0.8571
# Epoch 19/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.4299 - accuracy: 0.8490 - val_loss: 0.3961 - val_accuracy: 0.8622
# Epoch 20/200
# 12/12 [==============================] - 33s 3s/step - loss: 0.3970 - accuracy: 0.8880 - val_loss: 0.3854 - val_accuracy: 0.8571
# Epoch 21/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.3554 - accuracy: 0.8942 - val_loss: 0.3918 - val_accuracy: 0.8673
# Epoch 22/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.3337 - accuracy: 0.8984 - val_loss: 0.3600 - val_accuracy: 0.8724
# Epoch 23/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.3251 - accuracy: 0.9089 - val_loss: 0.3477 - val_accuracy: 0.8724
# Epoch 24/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.3014 - accuracy: 0.9220 - val_loss: 0.3383 - val_accuracy: 0.8929
# Epoch 25/200
# 12/12 [==============================] - 25s 2s/step - loss: 0.2895 - accuracy: 0.9219 - val_loss: 0.3445 - val_accuracy: 0.8980
# Epoch 26/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.2602 - accuracy: 0.9245 - val_loss: 0.3337 - val_accuracy: 0.8929
# Epoch 27/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.2922 - accuracy: 0.9193 - val_loss: 0.3222 - val_accuracy: 0.8724
# Epoch 28/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.2337 - accuracy: 0.9375 - val_loss: 0.3119 - val_accuracy: 0.8929
# Epoch 29/200
# 12/12 [==============================] - 20s 2s/step - loss: 0.2328 - accuracy: 0.9453 - val_loss: 0.3112 - val_accuracy: 0.8929
# Epoch 30/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.2140 - accuracy: 0.9304 - val_loss: 0.3031 - val_accuracy: 0.8980
# Epoch 31/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.2752 - accuracy: 0.9081 - val_loss: 0.3152 - val_accuracy: 0.8776
# Epoch 32/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.2330 - accuracy: 0.9415 - val_loss: 0.3033 - val_accuracy: 0.8878
# Epoch 33/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.2186 - accuracy: 0.9427 - val_loss: 0.3057 - val_accuracy: 0.8827
# Epoch 34/200
# 12/12 [==============================] - 26s 2s/step - loss: 0.1780 - accuracy: 0.9609 - val_loss: 0.3039 - val_accuracy: 0.8724
# Epoch 35/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.1856 - accuracy: 0.9499 - val_loss: 0.2872 - val_accuracy: 0.8878
# Epoch 36/200
# 12/12 [==============================] - 20s 2s/step - loss: 0.1935 - accuracy: 0.9531 - val_loss: 0.2820 - val_accuracy: 0.9082
# Epoch 37/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.1607 - accuracy: 0.9694 - val_loss: 0.2801 - val_accuracy: 0.8929
# Epoch 38/200
# 12/12 [==============================] - 18s 2s/step - loss: 0.1810 - accuracy: 0.9443 - val_loss: 0.2878 - val_accuracy: 0.8929
# Epoch 39/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.1743 - accuracy: 0.9554 - val_loss: 0.2839 - val_accuracy: 0.9082
# Epoch 40/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.1847 - accuracy: 0.9505 - val_loss: 0.2644 - val_accuracy: 0.9031
# Epoch 41/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.1419 - accuracy: 0.9740 - val_loss: 0.2627 - val_accuracy: 0.9082
# Epoch 42/200
# 12/12 [==============================] - 20s 2s/step - loss: 0.1643 - accuracy: 0.9557 - val_loss: 0.2661 - val_accuracy: 0.8929
# Epoch 43/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.1506 - accuracy: 0.9583 - val_loss: 0.2658 - val_accuracy: 0.9031
# Epoch 44/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.1461 - accuracy: 0.9526 - val_loss: 0.2605 - val_accuracy: 0.8929
# Epoch 45/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.1156 - accuracy: 0.9766 - val_loss: 0.2573 - val_accuracy: 0.8980
# Epoch 46/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.1216 - accuracy: 0.9714 - val_loss: 0.2499 - val_accuracy: 0.9133
# Epoch 47/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.1245 - accuracy: 0.9694 - val_loss: 0.2538 - val_accuracy: 0.9031
# Epoch 48/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.1130 - accuracy: 0.9694 - val_loss: 0.2563 - val_accuracy: 0.8980
# Epoch 49/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.1313 - accuracy: 0.9610 - val_loss: 0.2447 - val_accuracy: 0.9031
# Epoch 50/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.1319 - accuracy: 0.9661 - val_loss: 0.2436 - val_accuracy: 0.9133
# Epoch 51/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.1250 - accuracy: 0.9609 - val_loss: 0.2597 - val_accuracy: 0.8980
# Epoch 52/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0993 - accuracy: 0.9740 - val_loss: 0.2711 - val_accuracy: 0.9031
# Epoch 53/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.1011 - accuracy: 0.9792 - val_loss: 0.2617 - val_accuracy: 0.8929
# Epoch 54/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0941 - accuracy: 0.9889 - val_loss: 0.2565 - val_accuracy: 0.9031
# Epoch 55/200
# 12/12 [==============================] - 26s 2s/step - loss: 0.0886 - accuracy: 0.9833 - val_loss: 0.2487 - val_accuracy: 0.9184
# Epoch 56/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0948 - accuracy: 0.9889 - val_loss: 0.2579 - val_accuracy: 0.8980
# Epoch 57/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0868 - accuracy: 0.9805 - val_loss: 0.2621 - val_accuracy: 0.9031
# Epoch 58/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0769 - accuracy: 0.9889 - val_loss: 0.2419 - val_accuracy: 0.9082
# Epoch 59/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0630 - accuracy: 0.9889 - val_loss: 0.2350 - val_accuracy: 0.9082
# Epoch 60/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0939 - accuracy: 0.9777 - val_loss: 0.2416 - val_accuracy: 0.9133
# Epoch 61/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0704 - accuracy: 0.9861 - val_loss: 0.2571 - val_accuracy: 0.9031
# Epoch 62/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0759 - accuracy: 0.9889 - val_loss: 0.2611 - val_accuracy: 0.9133
# Epoch 63/200
# 12/12 [==============================] - 20s 2s/step - loss: 0.0839 - accuracy: 0.9844 - val_loss: 0.2397 - val_accuracy: 0.9133
# Epoch 64/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0790 - accuracy: 0.9861 - val_loss: 0.2424 - val_accuracy: 0.9133
# Epoch 65/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0739 - accuracy: 0.9861 - val_loss: 0.2481 - val_accuracy: 0.9184
# Epoch 66/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0613 - accuracy: 0.9889 - val_loss: 0.2398 - val_accuracy: 0.9184
# Epoch 67/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0527 - accuracy: 0.9972 - val_loss: 0.2457 - val_accuracy: 0.9082
# Epoch 68/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0551 - accuracy: 0.9896 - val_loss: 0.2513 - val_accuracy: 0.9133
# Epoch 69/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.0693 - accuracy: 0.9922 - val_loss: 0.2627 - val_accuracy: 0.9031
# Epoch 70/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0598 - accuracy: 0.9844 - val_loss: 0.2467 - val_accuracy: 0.9082
# Epoch 71/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0600 - accuracy: 0.9889 - val_loss: 0.2400 - val_accuracy: 0.9184
# Epoch 72/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0621 - accuracy: 0.9916 - val_loss: 0.2418 - val_accuracy: 0.9184
# Epoch 73/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0427 - accuracy: 0.9972 - val_loss: 0.2463 - val_accuracy: 0.9133
# Epoch 74/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0574 - accuracy: 0.9889 - val_loss: 0.2463 - val_accuracy: 0.9184
# Epoch 75/200
# 12/12 [==============================] - 26s 2s/step - loss: 0.0549 - accuracy: 0.9861 - val_loss: 0.2479 - val_accuracy: 0.9133
# Epoch 76/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0606 - accuracy: 0.9889 - val_loss: 0.2386 - val_accuracy: 0.9184
# Epoch 77/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0487 - accuracy: 0.9889 - val_loss: 0.2381 - val_accuracy: 0.9235
# Epoch 78/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0536 - accuracy: 0.9889 - val_loss: 0.2443 - val_accuracy: 0.9082
# Epoch 79/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0406 - accuracy: 0.9916 - val_loss: 0.2400 - val_accuracy: 0.9133
# Epoch 80/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.0526 - accuracy: 0.9948 - val_loss: 0.2336 - val_accuracy: 0.9133
# Epoch 81/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0409 - accuracy: 0.9972 - val_loss: 0.2431 - val_accuracy: 0.9184
# Epoch 82/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.0379 - accuracy: 0.9974 - val_loss: 0.2469 - val_accuracy: 0.9184
# Epoch 83/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0504 - accuracy: 0.9916 - val_loss: 0.2533 - val_accuracy: 0.9082
# Epoch 84/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0372 - accuracy: 0.9972 - val_loss: 0.2553 - val_accuracy: 0.9184
# Epoch 85/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0397 - accuracy: 0.9948 - val_loss: 0.2451 - val_accuracy: 0.9184
# Epoch 86/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.0421 - accuracy: 0.9974 - val_loss: 0.2389 - val_accuracy: 0.9184
# Epoch 87/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0408 - accuracy: 1.0000 - val_loss: 0.2411 - val_accuracy: 0.9184
# Epoch 88/200
# 12/12 [==============================] - 18s 2s/step - loss: 0.0397 - accuracy: 0.9944 - val_loss: 0.2383 - val_accuracy: 0.9235
# Epoch 89/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0474 - accuracy: 0.9916 - val_loss: 0.2396 - val_accuracy: 0.9184
# Epoch 90/200
# 12/12 [==============================] - 20s 2s/step - loss: 0.0415 - accuracy: 0.9896 - val_loss: 0.2438 - val_accuracy: 0.9286
# Epoch 91/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0369 - accuracy: 0.9948 - val_loss: 0.2368 - val_accuracy: 0.9235
# Epoch 92/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0292 - accuracy: 0.9916 - val_loss: 0.2331 - val_accuracy: 0.9235
# Epoch 93/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0263 - accuracy: 0.9944 - val_loss: 0.2291 - val_accuracy: 0.9286
# Epoch 94/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.2291 - val_accuracy: 0.9286
# Epoch 95/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.0274 - accuracy: 1.0000 - val_loss: 0.2328 - val_accuracy: 0.9235
# Epoch 96/200
# 12/12 [==============================] - 18s 2s/step - loss: 0.0430 - accuracy: 0.9944 - val_loss: 0.2388 - val_accuracy: 0.9235
# Epoch 97/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0449 - accuracy: 0.9922 - val_loss: 0.2340 - val_accuracy: 0.9286
# Epoch 98/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0321 - accuracy: 0.9974 - val_loss: 0.2252 - val_accuracy: 0.9235
# Epoch 99/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0235 - accuracy: 0.9972 - val_loss: 0.2244 - val_accuracy: 0.9184
# Epoch 100/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0289 - accuracy: 0.9974 - val_loss: 0.2291 - val_accuracy: 0.9184
# Epoch 101/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0303 - accuracy: 1.0000 - val_loss: 0.2269 - val_accuracy: 0.9133
# Epoch 102/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0283 - accuracy: 0.9974 - val_loss: 0.2454 - val_accuracy: 0.9184
# Epoch 103/200
# 12/12 [==============================] - 18s 2s/step - loss: 0.0283 - accuracy: 0.9944 - val_loss: 0.2415 - val_accuracy: 0.9184
# Epoch 104/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0244 - accuracy: 0.9974 - val_loss: 0.2286 - val_accuracy: 0.9184
# Epoch 105/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0218 - accuracy: 0.9944 - val_loss: 0.2277 - val_accuracy: 0.9184
# Epoch 106/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0252 - accuracy: 0.9972 - val_loss: 0.2341 - val_accuracy: 0.9286
# Epoch 107/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0238 - accuracy: 0.9974 - val_loss: 0.2399 - val_accuracy: 0.9184
# Epoch 108/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.2558 - val_accuracy: 0.9082
# Epoch 109/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0239 - accuracy: 0.9974 - val_loss: 0.2502 - val_accuracy: 0.9184
# Epoch 110/200
# 12/12 [==============================] - 25s 2s/step - loss: 0.0226 - accuracy: 0.9974 - val_loss: 0.2397 - val_accuracy: 0.9184
# Epoch 111/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0266 - accuracy: 0.9944 - val_loss: 0.2416 - val_accuracy: 0.9235
# Epoch 112/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0236 - accuracy: 0.9972 - val_loss: 0.2424 - val_accuracy: 0.9235
# Epoch 113/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0274 - accuracy: 0.9974 - val_loss: 0.2393 - val_accuracy: 0.9184
# Epoch 114/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0367 - accuracy: 0.9896 - val_loss: 0.2408 - val_accuracy: 0.9184
# Epoch 115/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.2370 - val_accuracy: 0.9286
# Epoch 116/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.2379 - val_accuracy: 0.9235
# Epoch 117/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.2337 - val_accuracy: 0.9184
# Epoch 118/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0228 - accuracy: 0.9948 - val_loss: 0.2365 - val_accuracy: 0.9184
# Epoch 119/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.2380 - val_accuracy: 0.9184
# Epoch 120/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.2398 - val_accuracy: 0.9184
# Epoch 121/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.2412 - val_accuracy: 0.9184
# Epoch 122/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0193 - accuracy: 0.9944 - val_loss: 0.2372 - val_accuracy: 0.9286
# Epoch 123/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.2323 - val_accuracy: 0.9337
# Epoch 124/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0216 - accuracy: 1.0000 - val_loss: 0.2366 - val_accuracy: 0.9235
# Epoch 125/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.0197 - accuracy: 0.9948 - val_loss: 0.2435 - val_accuracy: 0.9133
# Epoch 126/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0279 - accuracy: 0.9944 - val_loss: 0.2512 - val_accuracy: 0.9082
# Epoch 127/200
# 12/12 [==============================] - 20s 2s/step - loss: 0.0175 - accuracy: 0.9972 - val_loss: 0.2404 - val_accuracy: 0.9184
# Epoch 128/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.0203 - accuracy: 0.9948 - val_loss: 0.2359 - val_accuracy: 0.9286
# Epoch 129/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0214 - accuracy: 0.9974 - val_loss: 0.2344 - val_accuracy: 0.9133
# Epoch 130/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.2397 - val_accuracy: 0.9082
# Epoch 131/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.2365 - val_accuracy: 0.9082
# Epoch 132/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0257 - accuracy: 0.9922 - val_loss: 0.2368 - val_accuracy: 0.9235
# Epoch 133/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.2315 - val_accuracy: 0.9133
# Epoch 134/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.2350 - val_accuracy: 0.9184
# Epoch 135/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.2372 - val_accuracy: 0.9184
# Epoch 136/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.2366 - val_accuracy: 0.9133
# Epoch 137/200
# 12/12 [==============================] - 20s 2s/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.2336 - val_accuracy: 0.9133
# Epoch 138/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0170 - accuracy: 0.9974 - val_loss: 0.2363 - val_accuracy: 0.9133
# Epoch 139/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.2389 - val_accuracy: 0.9184
# Epoch 140/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.2410 - val_accuracy: 0.9235
# Epoch 141/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0161 - accuracy: 0.9972 - val_loss: 0.2392 - val_accuracy: 0.9235
# Epoch 142/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0131 - accuracy: 0.9972 - val_loss: 0.2417 - val_accuracy: 0.9235
# Epoch 143/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.2449 - val_accuracy: 0.9286
# Epoch 144/200
# 12/12 [==============================] - 18s 2s/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.2452 - val_accuracy: 0.9286
# Epoch 145/200
# 12/12 [==============================] - 27s 2s/step - loss: 0.0149 - accuracy: 0.9974 - val_loss: 0.2488 - val_accuracy: 0.9133
# Epoch 146/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0195 - accuracy: 0.9944 - val_loss: 0.2718 - val_accuracy: 0.9184
# Epoch 147/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.2632 - val_accuracy: 0.9184
# Epoch 148/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0147 - accuracy: 0.9974 - val_loss: 0.2474 - val_accuracy: 0.9133
# Epoch 149/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.2445 - val_accuracy: 0.9235
# Epoch 150/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.2484 - val_accuracy: 0.9184
# Epoch 151/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2493 - val_accuracy: 0.9184
# Epoch 152/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0170 - accuracy: 0.9948 - val_loss: 0.2531 - val_accuracy: 0.9133
# Epoch 153/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.2517 - val_accuracy: 0.9133
# Epoch 154/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2444 - val_accuracy: 0.9184
# Epoch 155/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.0125 - accuracy: 0.9974 - val_loss: 0.2455 - val_accuracy: 0.9133
# Epoch 156/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.2568 - val_accuracy: 0.9184
# Epoch 157/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.2580 - val_accuracy: 0.9133
# Epoch 158/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.2491 - val_accuracy: 0.9184
# Epoch 159/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0137 - accuracy: 0.9974 - val_loss: 0.2504 - val_accuracy: 0.9133
# Epoch 160/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.2521 - val_accuracy: 0.9133
# Epoch 161/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2497 - val_accuracy: 0.9184
# Epoch 162/200
# 12/12 [==============================] - 20s 2s/step - loss: 0.0144 - accuracy: 0.9974 - val_loss: 0.2453 - val_accuracy: 0.9235
# Epoch 163/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2433 - val_accuracy: 0.9286
# Epoch 164/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.2430 - val_accuracy: 0.9286
# Epoch 165/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.2434 - val_accuracy: 0.9286
# Epoch 166/200
# 12/12 [==============================] - 26s 2s/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.2385 - val_accuracy: 0.9337
# Epoch 167/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2394 - val_accuracy: 0.9286
# Epoch 168/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2419 - val_accuracy: 0.9235
# Epoch 169/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.2406 - val_accuracy: 0.9184
# Epoch 170/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.2390 - val_accuracy: 0.9184
# Epoch 171/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.2407 - val_accuracy: 0.9235
# Epoch 172/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.2412 - val_accuracy: 0.9286
# Epoch 173/200
# 12/12 [==============================] - 20s 2s/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.2464 - val_accuracy: 0.9235
# Epoch 174/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.2531 - val_accuracy: 0.9235
# Epoch 175/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.2553 - val_accuracy: 0.9235
# Epoch 176/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.2508 - val_accuracy: 0.9235
# Epoch 177/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.2440 - val_accuracy: 0.9235
# Epoch 178/200
# 12/12 [==============================] - 25s 2s/step - loss: 0.0099 - accuracy: 0.9972 - val_loss: 0.2462 - val_accuracy: 0.9133
# Epoch 179/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.2441 - val_accuracy: 0.9337
# Epoch 180/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2453 - val_accuracy: 0.9337
# Epoch 181/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.2493 - val_accuracy: 0.9337
# Epoch 182/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.2531 - val_accuracy: 0.9286
# Epoch 183/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9286
# Epoch 184/200
# 12/12 [==============================] - 22s 2s/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.2519 - val_accuracy: 0.9286
# Epoch 185/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2472 - val_accuracy: 0.9337
# Epoch 186/200
# 12/12 [==============================] - 18s 2s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.2457 - val_accuracy: 0.9337
# Epoch 187/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2511 - val_accuracy: 0.9337
# Epoch 188/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.2552 - val_accuracy: 0.9337
# Epoch 189/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.2632 - val_accuracy: 0.9286
# Epoch 190/200
# 12/12 [==============================] - 25s 2s/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.2585 - val_accuracy: 0.9184
# Epoch 191/200
# 12/12 [==============================] - 20s 2s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.2582 - val_accuracy: 0.9184
# Epoch 192/200
# 12/12 [==============================] - 20s 2s/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.2609 - val_accuracy: 0.9235
# Epoch 193/200
# 12/12 [==============================] - 20s 2s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.2640 - val_accuracy: 0.9235
# Epoch 194/200
# 12/12 [==============================] - 18s 2s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.2641 - val_accuracy: 0.9184
# Epoch 195/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2620 - val_accuracy: 0.9082
# Epoch 196/200
# 12/12 [==============================] - 19s 2s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2582 - val_accuracy: 0.9184
# Epoch 197/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0066 - accuracy: 0.9974 - val_loss: 0.2572 - val_accuracy: 0.9184
# Epoch 198/200
# 12/12 [==============================] - 24s 2s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.2575 - val_accuracy: 0.9184
# Epoch 199/200
# 12/12 [==============================] - 23s 2s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.2538 - val_accuracy: 0.9235
# Epoch 200/200
# 12/12 [==============================] - 21s 2s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.2566 - val_accuracy: 0.9337

# %%
# Membuat plot akurasi model ResNet50
plt.figure(figsize=(10, 4))
plt.plot(range(1, len(resnet_hist.history['accuracy']) + 1), resnet_hist.history['accuracy'])
plt.plot(range(1, len(resnet_hist.history['val_accuracy']) + 1), resnet_hist.history['val_accuracy'])
plt.title('ResNet50 model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.grid(True)

# Place the legend outside the plot
plt.legend(['training', 'validation'], loc='upper left', bbox_to_anchor=(1, 1))

plt.show()

print()

# Membuat plot loss model ResNet50
plt.figure(figsize=(10, 4))
plt.plot(range(1, len(resnet_hist.history['loss']) + 1), resnet_hist.history['loss'])
plt.plot(range(1, len(resnet_hist.history['val_loss']) + 1), resnet_hist.history['val_loss'])
plt.title('ResNet50 model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.grid(True)

# Place the legend outside the plot
plt.legend(['training', 'validation'], loc='upper left', bbox_to_anchor=(1, 1))

plt.show()

# %%
# Ambil data akurasi dan loss dari riwayat pelatihan
training_accuracy = resnet_hist.history['accuracy']
validation_accuracy = resnet_hist.history['val_accuracy']
training_loss = resnet_hist.history['loss']
validation_loss = resnet_hist.history['val_loss']

# Hitung nilai rata-rata
average_training_accuracy = np.mean(training_accuracy)
average_validation_accuracy = np.mean(validation_accuracy)
average_training_loss = np.mean(training_loss)
average_validation_loss = np.mean(validation_loss)

print(f"Average Training Accuracy: {average_training_accuracy:.4f}")
print(f"Average Validation Accuracy: {average_validation_accuracy:.4f}")
print(f"Average Training Loss: {average_training_loss:.4f}")
print(f"Average Validation Loss: {average_validation_loss:.4f}")
# Out:
# Average Training Accuracy: 0.9590
# Average Validation Accuracy: 0.9001
# Average Training Loss: 0.1482
# Average Validation Loss: 0.3113

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have valid_y_true and valid_y_pred defined

# Evaluate the model on the validation data
valid_predictions = resnet_model.predict(valid_data)
valid_y_pred = np.argmax(valid_predictions, axis=1)  # Use argmax for multiclass predictions
valid_y_true = valid_data.classes  # Use the validation data labels

# Calculate accuracy for the validation dataset
valid_accuracy = accuracy_score(valid_y_true, valid_y_pred)
print(f"Validation Accuracy: {valid_accuracy:.4f}")

# Generate a classification report for the validation dataset
valid_class_report = classification_report(valid_y_true, valid_y_pred)
print("Validation Classification Report:")
print(valid_class_report)

# Generate a confusion matrix for the validation dataset
valid_confusion_mat = confusion_matrix(valid_y_true, valid_y_pred)
print("Validation Confusion Matrix:")
print(valid_confusion_mat)

# Create a heatmap for the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(valid_confusion_mat, annot=True, fmt='d', cmap='Blues', xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion Matrix - Validation Dataset')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# 7/7 [==============================] - 8s 987ms/step
# Validation Accuracy: 0.1531
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.19      0.19      0.19        21
#            1       0.09      0.09      0.09        22
#            2       0.10      0.10      0.10        20
#            3       0.18      0.19      0.19        21
#            4       0.17      0.18      0.17        22
#            5       0.11      0.10      0.11        20
#            6       0.21      0.20      0.20        25
#            7       0.24      0.23      0.23        22
#            8       0.09      0.09      0.09        23
#
#     accuracy                           0.15       196
#    macro avg       0.15      0.15      0.15       196
# weighted avg       0.15      0.15      0.15       196
#
# Validation Confusion Matrix:
# [[4 5 1 2 1 0 3 2 3]
#  [3 2 2 2 2 3 4 0 4]
#  [1 4 2 2 3 1 2 3 2]
#  [2 2 2 4 4 2 1 3 1]
#  [2 1 3 1 4 4 3 2 2]
#  [1 3 1 4 0 2 3 3 3]
#  [2 1 2 2 4 4 5 1 4]
#  [4 2 2 3 2 0 2 5 2]
#  [2 3 5 2 4 2 1 2 2]]
